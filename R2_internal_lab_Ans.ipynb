# %% [markdown]
# # K nearest neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x, y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h: X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1. Read the problem statement.
#
# 2. Get the dataset.
#
# 3. Explore the dataset.
#
# 4. Pre-processing of dataset.
#
# 5. Visualization
#
# 6. Transform the dataset for building machine learning model.
#
# 7. Split data into train, test set.
#
# 8. Build Model.
#
# 9. Apply the model.
#
# 10. Evaluate the model.
#
# 11. Finding Optimal K value
#
# 12. Repeat 7, 8, 9 steps.

# %% [markdown]
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Download the dataset here:**
# - https://www.kaggle.com/uciml/iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Question 1
#
# Import the data set and print 10 random rows from the data set
#
# Hint: use **sample()** function to get random rows

# %%
import pandas as pd
df = pd.read_csv('iris.csv')
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 66    67            5.6           3.0            4.5           1.5
# 19    20            5.1           3.8            1.5           0.3
# 76    77            6.8           2.8            4.8           1.4
# 150  151            5.9           NaN            NaN           NaN
# 106  107            4.9           2.5            4.5           1.7
# 29    30            4.7           3.2            1.6           0.2
# 118  119            7.7           2.6            6.9           2.3
# 5      6            5.4           3.9            1.7           0.4
# 151  152            NaN           NaN            NaN           1.8
# 91    92            6.1           3.0            4.6           1.4
#
#              Species
# 66   Iris-versicolor
# 19       Iris-setosa
# 76   Iris-versicolor
# 150   Iris-virginica
# 106   Iris-virginica
# 29       Iris-setosa
# 118   Iris-virginica
# 5        Iris-setosa
# 151   Iris-virginica
# 91   Iris-versicolor

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Question 2 - Estimating missing values
#
# Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median)

# %% [markdown]
# Calculate the number of missing values per column
# - don't use loops

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    1
# SepalWidthCm     2
# PetalLengthCm    2
# PetalWidthCm     1
# Species          0
# dtype: int64

# %% [markdown]
# Fill missing values with median of that particular column

# %%
df.fillna(df.median(), inplace=True)

# %% [markdown]
# ### Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0 to 2)
#
# Hint: use **LabelEncoder()**

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 15    16            5.7           4.4            1.5           0.4        0
# 76    77            6.8           2.8            4.8           1.4        1
# 116  117            6.5           3.0            5.5           1.8        2
# 19    20            5.1           3.8            1.5           0.3        0
# 126  127            6.2           2.8            4.8           1.8        2
# 31    32            5.4           3.4            1.5           0.4        0
# 129  130            7.2           3.0            5.8           1.6        2
# 104  105            6.5           3.0            5.8           2.2        2
# 106  107            4.9           2.5            4.5           1.7        2
# 6      7            4.6           3.4            1.4           0.3        0

# %% [markdown]
# ### Question 4
#
# Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.
#
# Hint: use **corr()**

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.702734     -0.392693       0.872346
# SepalLengthCm  0.702734       1.000000     -0.109369       0.871120
# SepalWidthCm  -0.392693      -0.109369      1.000000      -0.420713
# PetalLengthCm  0.872346       0.871120     -0.420713       1.000000
# PetalWidthCm   0.890676       0.815986     -0.356510       0.962043
# Species        0.942753       0.775061     -0.417318       0.944477
#
#                PetalWidthCm   Species
# Id                 0.890676  0.942753
# SepalLengthCm      0.815986  0.775061
# SepalWidthCm      -0.356510 -0.417318
# PetalLengthCm      0.962043  0.944477
# PetalWidthCm       1.000000  0.952513
# Species            0.952513  1.000000

# %%
df.loc[:, (df.corr()['Species'] <= -0.1) | (df.corr()['Species'] >= 0.1)].head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ### Question 5
#
# Observe the independent variables variance and drop such variables having no variance or almost zero variance (variance < 0.1). They will be having almost no influence on the classification
#
# Hint: use **var()**

# %%
df.var()
# Out:
# Id               1938.000000
# SepalLengthCm       0.676645
# SepalWidthCm        0.185552
# PetalLengthCm       3.076516
# PetalWidthCm        0.577141
# Species             0.675322
# dtype: float64

# %% [markdown]
# ### Question 6
#
# Plot the scatter matrix for all the variables.
#
# Hint: use **pandas.plotting.scatter_matrix()**
#
# you can also use pairplot()

# %%
pd.plotting.scatter_matrix(df, c= df['Species'],figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3216A9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B32147128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B321646A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B32098C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B320762E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B320A4978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B32065B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3204BB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3204BC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3203B7B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322FDB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322F07F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B32318E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322DAB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322B30B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322C8C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31D63748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31CA9B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31C26B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31BBDEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31AFCBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31ADC9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31AD4748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31AC0C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31AB04A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31AA8AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31A975C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B31A8EEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B2FD9B668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B316A4DA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3202C4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B32052780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3237C978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322D5358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B322847B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B32248CF8>]],
#       dtype=object)

# %% [markdown]
# ## Split the dataset into training and test sets

# %% [markdown]
# ### Question 7
#
# Split the dataset into training and test sets with 80-20 ratio
#
# Hint: use **train_test_split()**

# %%
import numpy as no
from sklearn.model_selection import train_test_split

x= df.drop(['Species','Id'],axis=1)
y=df['Species']

X_train,X_test,Y_train,Y_test,= train_test_split(x,y,test_size=0.2,random_state=7)

# %%
print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)
# Out:
# (121, 4)
# (121,)
# (31, 4)
# (31,)

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 8
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for k in [3, 5, 9]:
  model = KNeighborsClassifier(n_neighbors = k)    
  model.fit(X_train, Y_train)                      
  y_pred = model.predict(X_test)                   
  print(accuracy_score(Y_test, y_pred))
# Out:
# 0.9354838709677419
# 0.967741935483871
# 0.9032258064516129

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 9 - Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %%
ac_scores = []

for k in range(1, 20, 2) :
  model = KNeighborsClassifier(n_neighbors = k)    
  model.fit(X_train, Y_train)                      
  y_pred = model.predict(X_test)                   
  score = accuracy_score(Y_test, y_pred)           
  ac_scores.append((score, k))                     
  
print("The max accuracy and optimal number of neighbors is {}".format(max(ac_scores)))
# Out:
# The max accuracy and optimal number of neighbors is (0.967741935483871, 5)

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 10
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %%
import matplotlib.pyplot as plt

score, k = zip(*ac_scores)
plt.plot(k, score)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Accuracy score')
plt.show()

# %% [markdown]
# # Breast cancer dataset - OPTIONAL

# %% [markdown]
# ## Read data

# %% [markdown]
# ### Question 1
# Read the data given in bc2.csv file

# %%
import pandas as pd
df = pd.read_csv('bc2.csv')
df.sample(10)
# Out:
#           ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 618  1061990               4          1           1                  1
# 215  1222936               8          7           8                  7
# 497  1182404               4          2           1                  1
# 18   1050670              10          7           7                  6
# 455  1246562              10          2           2                  1
# 419  1253505               2          3           1                  1
# 556  1321264               5          2           2                  2
# 121  1174057               4          2           1                  1
# 468  1105524               4          1           1                  1
# 543  1184586               4          1           1                  1
#
#      Single Epithelial Cell Size Bare Nuclei  Normal Nucleoli  \
# 618                            2           1                2
# 215                            5           5                5
# 497                            2           1                1
# 18                             4          10                4
# 455                            2           6                1
# 419                            5           1                1
# 556                            1           1                2
# 121                            2           2                3
# 468                            2           1                1
# 543                            2           1                2
#
#      Bland Chromatin  Mitoses  Class
# 618                1        1      2
# 215               10        2      4
# 497                1        1      2
# 18                 1        2      4
# 455                1        2      4
# 419                1        1      2
# 556                1        1      2
# 121                1        1      2
# 468                1        1      2
# 543                1        1      2

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Question 2
# Observe the no.of records in dataset and type of each column

# %%
df.dtypes
# Out:
# ID                              int64
# ClumpThickness                  int64
# Cell Size                       int64
# Cell Shape                      int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Normal Nucleoli                 int64
# Bland Chromatin                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %% [markdown]
# ### Question 3
# Use summary statistics to check if missing values, outlier and encoding treament is necessary
#
# Hint: use **describe()**

# %%
df.describe()
# Out:
#                  ID  ClumpThickness   Cell Size  Cell Shape  \
# count  6.990000e+02      699.000000  699.000000  699.000000
# mean   1.071704e+06        4.417740    3.134478    3.207439
# std    6.170957e+05        2.815741    3.051459    2.971913
# min    6.163400e+04        1.000000    1.000000    1.000000
# 25%    8.706885e+05        2.000000    1.000000    1.000000
# 50%    1.171710e+06        4.000000    1.000000    1.000000
# 75%    1.238298e+06        6.000000    5.000000    5.000000
# max    1.345435e+07       10.000000   10.000000   10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Normal Nucleoli  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     2.000000         2.000000
# 50%             1.000000                     2.000000         3.000000
# 75%             4.000000                     4.000000         5.000000
# max            10.000000                    10.000000        10.000000
#
#        Bland Chromatin     Mitoses       Class
# count       699.000000  699.000000  699.000000
# mean          2.866953    1.589413    2.689557
# std           3.053634    1.715078    0.951273
# min           1.000000    1.000000    2.000000
# 25%           1.000000    1.000000    2.000000
# 50%           1.000000    1.000000    2.000000
# 75%           4.000000    1.000000    4.000000
# max          10.000000   10.000000    4.000000

# %% [markdown]
# #### Check Missing Values

# %%
df.isna().sum()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# ### Question 4
# #### Check how many `?` are there in Bare Nuclei feature (they are also unknown or missing values).

# %%
df[df['Bare Nuclei']=='?']['Bare Nuclei'].count()
# Out:
# 16

# %% [markdown]
# #### Replace them with the 'top' value of the describe function of Bare Nuclei feature
#
# Hint: give value of parameter include='all' in describe function

# %%
df=df.replace('?',df['Bare Nuclei'].describe().top)

# %%
df[df['Bare Nuclei']=='?']['Bare Nuclei'].count()
# Out:
# 0

# %% [markdown]
# ### Question 5
# #### Find the distribution of target variable (Class)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df['Class'])

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %%
plt.hist(df['Class'])
# Out:
# (array([458.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 241.]),
#  array([2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Convert the datatype of Bare Nuclei to `int`

# %%
df['Bare Nuclei']= df['Bare Nuclei'].apply(pd.to_numeric)

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# ### Question 6
# Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
pd.plotting.scatter_matrix(df, c=df['Class'], figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A539400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39E124A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39E36A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39E5FF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39E8F550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39EB9AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39EE8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39F11630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39F11668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39F67128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39F8E630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39FB7BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B39FE7160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A00C6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A036C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A065208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A08C780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A0B5CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A0E62B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A10B828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A133DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A164358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A18A8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A1B4E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A1E4400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A20A978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A232EF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A2624A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A28AA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A2B1F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A2E0550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A308AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A33A080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A3605F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A389B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A3B9128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A3DF6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A408C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A4381D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A45D748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A486CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A4B9278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3A4DF7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BB95D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BBC6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BBEE898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BC13E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BC473C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BC6D940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BC93EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BCC6470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BCEC9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BD13F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BD45518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BD6AA90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BD9F048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BDC65C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BDEEB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BE1F0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BE46668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BE6FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BEA1198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BEC9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BEF1C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BF23240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BF477B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BF72D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BFA22E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BFCA860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3BFF4DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C024390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C04C908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C075E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C0A6438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C0CD9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C0F5F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C1274E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C14FA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C176FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C1A7588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C1CFB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C2000B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C227630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C24FBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C281160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C2A86D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C2D2C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C301208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C32B780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C351CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C3842B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C3AB828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C3D4DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C404358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C42B8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C454E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C484400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C4AE978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C4D6EF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C4FCCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C52E278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C5547F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C57BD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C5AD320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C5D4898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C5FEE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C62F3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C656940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C680EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C6B1470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C6D89E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C700F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C730518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C75AA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C78B048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C7B25C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C7DAB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C80A0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C832668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C85ABE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015B3C88A198>]],
#       dtype=object)

# %% [markdown]
# ## Train test split

# %% [markdown]
# ### Question 7
# #### Divide the dataset into feature set and target set

# %%
import numpy as np
from sklearn.model_selection import train_test_split


X = df.drop(['Class', 'ID'], axis=1) 
y = df['Class']

# %% [markdown]
# #### Divide the Training and Test sets in 70:30

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (489, 9)
# (489,)

# %%
print(X_test.shape)
print(Y_test.shape)
# Out:
# (210, 9)
# (210,)

# %% [markdown]
# ## Scale the data

# %% [markdown]
# ### Question 8
# Standardize the data
#
# Hint: use **StandardScaler()**

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled=scalar.fit_transform(X_test)
print("X_Trained Standardized : {}".format(X_train_scaled))
print("X_Test Standardized : {}".format(X_test_scaled))
# Out:
# X_Trained Standardized : [[ 1.22882709  0.26682751  0.59488028 ...  1.46053872  0.04638448
#   -0.34871138]
#  [-0.15812374 -0.70447759 -0.74720257 ... -1.03086861 -0.61106513
#   -0.34871138]
#  [-0.50486145 -0.70447759 -0.74720257 ... -1.03086861 -0.61106513
#   -0.34871138]
#  ...
#  [ 0.18861397 -0.70447759 -0.41168186 ... -0.2003995  -0.61106513
#   -0.34871138]
#  [ 1.22882709  0.26682751  0.25935957 ...  1.46053872  1.69000852
#    0.20313284]
#  [ 0.18861397  1.56190097  1.26592171 ...  0.63006961  1.36128371
#   -0.34871138]]
# X_Test Standardized : [[ 1.39035423  0.32569802  2.3224695  ...  1.46769208  2.31500235
#   -0.33713279]
#  [-1.2605157  -0.35149588 -0.05498883 ... -0.53370621 -0.61361508
#   -0.33713279]
#  [-0.12442859 -0.69009283 -0.73426264 ... -0.93398587 -0.61361508
#   -0.33713279]
#  ...
#  [-0.50312429 -0.69009283 -0.73426264 ... -0.53370621 -0.61361508
#   -0.33713279]
#  [-1.2605157  -0.69009283 -0.73426264 ... -0.13342655 -0.61361508
#   -0.33713279]
#  [ 1.76904993  2.3572797   2.3224695  ...  2.66853105  2.31500235
#    5.84909032]]
# C:\Users\Ajay anand\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Ajay anand\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\Ajay anand\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Ajay anand\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 9
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for k in [3, 5, 9]:
  model = KNeighborsClassifier(n_neighbors = k)    
  model.fit(X_train, Y_train)                      
  y_pred = model.predict(X_test)                
  print(accuracy_score(Y_test, y_pred))
# Out:
# 0.9619047619047619
# 0.9523809523809523
# 0.9428571428571428

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 10
# Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %%
ac_scores = []

for k in range(1, 20, 2) :
  model = KNeighborsClassifier(n_neighbors = k)   
  model.fit(X_train, Y_train)                     
  y_pred = model.predict(X_test)                  
  score = accuracy_score(Y_test, y_pred)          
  ac_scores.append((score, k))                    
  

print("The max accuracy and optimal number of neighbors is {}".format(max(ac_scores)))
# Out:
# The max accuracy and optimal number of neighbors is (0.9619047619047619, 3)

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 11
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %%
import matplotlib.pyplot as plt

score, k = zip(*ac_scores)
plt.plot(k, score)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Accuracy score')
plt.show()
